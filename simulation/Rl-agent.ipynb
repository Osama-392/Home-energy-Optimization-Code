# %%
pip install stable-baselines3[extra] gym
# Out:
# Requirement already satisfied: gym in c:\python\lib\site-packages (0.26.2)
# Requirement already satisfied: stable-baselines3[extra] in c:\python\lib\site-packages (2.5.0)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in c:\python\lib\site-packages (from stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\python\lib\site-packages (from stable-baselines3[extra]) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\python\lib\site-packages (from stable-baselines3[extra]) (2.6.0)
# Requirement already satisfied: cloudpickle in c:\python\lib\site-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: pandas in c:\python\lib\site-packages (from stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: matplotlib in c:\python\lib\site-packages (from stable-baselines3[extra]) (3.10.0)
# Collecting opencv-python (from stable-baselines3[extra])
#   Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting pygame (from stable-baselines3[extra])
#   Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\python\lib\site-packages (from stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: psutil in c:\users\osama\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (6.1.0)
# Collecting tqdm (from stable-baselines3[extra])
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: rich in c:\python\lib\site-packages (from stable-baselines3[extra]) (13.9.4)
# Collecting ale-py>=0.9.0 (from stable-baselines3[extra])
#   Downloading ale_py-0.11.1-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: pillow in c:\python\lib\site-packages (from stable-baselines3[extra]) (11.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\osama\appdata\roaming\python\python311\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\python\lib\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: filelock in c:\python\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.17.0)
# Requirement already satisfied: networkx in c:\python\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in c:\python\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.5)
# Requirement already satisfied: fsspec in c:\python\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\python\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\python\lib\site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: gym_notices>=0.0.4 in c:\python\lib\site-packages (from gym) (0.0.8)
# Requirement already satisfied: absl-py>=0.4 in c:\python\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\python\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.70.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\python\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: packaging in c:\users\osama\appdata\roaming\python\python311\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\python\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (5.29.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\python\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (65.5.0)
# Requirement already satisfied: six>1.9 in c:\users\osama\appdata\roaming\python\python311\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\python\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\python\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\python\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\python\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\osama\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python\lib\site-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python\lib\site-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\python\lib\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\osama\appdata\roaming\python\python311\site-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\python\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: colorama in c:\users\osama\appdata\roaming\python\python311\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Downloading ale_py-0.11.1-cp311-cp311-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.5 MB 2.8 MB/s eta 0:00:02
#    ------------------------ --------------- 2.1/3.5 MB 6.2 MB/s eta 0:00:01
#    ------------------------------------ --- 3.1/3.5 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 4.6 MB/s eta 0:00:00
# Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    --- ------------------------------------ 3.4/39.5 MB 16.7 MB/s eta 0:00:03
#    --- ------------------------------------ 3.4/39.5 MB 16.7 MB/s eta 0:00:03
#    ------ --------------------------------- 6.8/39.5 MB 11.0 MB/s eta 0:00:03
#    -------- ------------------------------- 8.1/39.5 MB 10.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.7/39.5 MB 10.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.8/39.5 MB 9.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.8/39.5 MB 9.6 MB/s eta 0:00:03
#    ------------- -------------------------- 12.8/39.5 MB 7.5 MB/s eta 0:00:04
#    ------------- -------------------------- 13.6/39.5 MB 7.3 MB/s eta 0:00:04
#    -------------- ------------------------- 14.2/39.5 MB 7.1 MB/s eta 0:00:04
#    --------------- ------------------------ 14.9/39.5 MB 6.4 MB/s eta 0:00:04
#    --------------- ------------------------ 15.5/39.5 MB 6.1 MB/s eta 0:00:04
#    --------------- ------------------------ 15.7/39.5 MB 5.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 16.0/39.5 MB 5.6 MB/s eta 0:00:05
#    ---------------- ----------------------- 16.3/39.5 MB 5.3 MB/s eta 0:00:05
#    ---------------- ----------------------- 16.5/39.5 MB 5.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 16.8/39.5 MB 4.8 MB/s eta 0:00:05
#    ----------------- ---------------------- 17.0/39.5 MB 4.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 17.3/39.5 MB 4.4 MB/s eta 0:00:06
#    ----------------- ---------------------- 17.6/39.5 MB 4.2 MB/s eta 0:00:06
#    ------------------ --------------------- 17.8/39.5 MB 4.1 MB/s eta 0:00:06
#    ------------------ --------------------- 18.1/39.5 MB 4.0 MB/s eta 0:00:06
#    ------------------ --------------------- 18.4/39.5 MB 3.9 MB/s eta 0:00:06
#    ------------------- -------------------- 18.9/39.5 MB 3.7 MB/s eta 0:00:06
#    ------------------- -------------------- 19.1/39.5 MB 3.6 MB/s eta 0:00:06
#    ------------------- -------------------- 19.4/39.5 MB 3.5 MB/s eta 0:00:06
#    ------------------- -------------------- 19.7/39.5 MB 3.4 MB/s eta 0:00:06
#    -------------------- ------------------- 19.9/39.5 MB 3.4 MB/s eta 0:00:06
#    -------------------- ------------------- 20.2/39.5 MB 3.3 MB/s eta 0:00:06
#    -------------------- ------------------- 20.7/39.5 MB 3.2 MB/s eta 0:00:06
#    --------------------- ------------------ 21.0/39.5 MB 3.2 MB/s eta 0:00:06
#    --------------------- ------------------ 21.2/39.5 MB 3.1 MB/s eta 0:00:06
#    --------------------- ------------------ 21.5/39.5 MB 3.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.8/39.5 MB 3.0 MB/s eta 0:00:06
#    ---------------------- ----------------- 22.0/39.5 MB 3.0 MB/s eta 0:00:06
#    ---------------------- ----------------- 22.3/39.5 MB 3.0 MB/s eta 0:00:06
#    ----------------------- ---------------- 22.8/39.5 MB 2.9 MB/s eta 0:00:06
#    ----------------------- ---------------- 23.1/39.5 MB 2.9 MB/s eta 0:00:06
#    ----------------------- ---------------- 23.3/39.5 MB 2.8 MB/s eta 0:00:06
#    ----------------------- ---------------- 23.6/39.5 MB 2.8 MB/s eta 0:00:06
#    ------------------------ --------------- 24.1/39.5 MB 2.8 MB/s eta 0:00:06
#    ------------------------ --------------- 24.4/39.5 MB 2.7 MB/s eta 0:00:06
#    ------------------------ --------------- 24.6/39.5 MB 2.7 MB/s eta 0:00:06
#    ------------------------- -------------- 24.9/39.5 MB 2.7 MB/s eta 0:00:06
#    ------------------------- -------------- 25.4/39.5 MB 2.6 MB/s eta 0:00:06
#    -------------------------- ------------- 25.7/39.5 MB 2.6 MB/s eta 0:00:06
#    -------------------------- ------------- 26.0/39.5 MB 2.6 MB/s eta 0:00:06
#    -------------------------- ------------- 26.5/39.5 MB 2.6 MB/s eta 0:00:06
#    --------------------------- ------------ 26.7/39.5 MB 2.6 MB/s eta 0:00:05
#    --------------------------- ------------ 27.0/39.5 MB 2.6 MB/s eta 0:00:05
#    --------------------------- ------------ 27.5/39.5 MB 2.5 MB/s eta 0:00:05
#    ---------------------------- ----------- 27.8/39.5 MB 2.5 MB/s eta 0:00:05
#    ---------------------------- ----------- 28.3/39.5 MB 2.5 MB/s eta 0:00:05
#    ---------------------------- ----------- 28.6/39.5 MB 2.5 MB/s eta 0:00:05
#    ----------------------------- ---------- 29.1/39.5 MB 2.5 MB/s eta 0:00:05
#    ------------------------------ --------- 29.6/39.5 MB 2.5 MB/s eta 0:00:04
#    ------------------------------ --------- 29.9/39.5 MB 2.5 MB/s eta 0:00:04
#    ------------------------------ --------- 30.4/39.5 MB 2.5 MB/s eta 0:00:04
#    ------------------------------- -------- 30.9/39.5 MB 2.5 MB/s eta 0:00:04
#    ------------------------------- -------- 31.5/39.5 MB 2.5 MB/s eta 0:00:04
#    -------------------------------- ------- 32.0/39.5 MB 2.5 MB/s eta 0:00:04
#    -------------------------------- ------- 32.5/39.5 MB 2.5 MB/s eta 0:00:03
#    --------------------------------- ------ 33.0/39.5 MB 2.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.8/39.5 MB 2.5 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.6/39.5 MB 2.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 35.1/39.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------------------ --- 35.9/39.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------------------ --- 36.4/39.5 MB 2.5 MB/s eta 0:00:02
#    ------------------------------------- -- 37.0/39.5 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 37.7/39.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  38.8/39.5 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 2.6 MB/s eta 0:00:00
# Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/10.6 MB 4.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/10.6 MB 4.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.1/10.6 MB 5.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/10.6 MB 5.3 MB/s eta 0:00:02
#    --------------------- ------------------ 5.8/10.6 MB 5.5 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/10.6 MB 5.7 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.6 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.6 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 5.9 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, pygame, opencv-python, ale-py
#
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    -------------------- ------------------- 2/4 [opencv-python]
#    ------------------------------ --------- 3/4 [ale-py]
#    ------------------------------ --------- 3/4 [ale-py]
#    ------------------------------ --------- 3/4 [ale-py]
#    ---------------------------------------- 4/4 [ale-py]
#
# Successfully installed ale-py-0.11.1 opencv-python-4.11.0.86 pygame-2.6.1 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (c:\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python\Lib\site-packages)

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import DummyVecEnv

# Wrap your environment
env = HEMSEnv()
check_env(env)  # Validate compatibility
vec_env = DummyVecEnv([lambda: env])

# Initialize PPO agent
model = PPO("MlpPolicy", vec_env, verbose=1)

# Train the agent
model.learn(total_timesteps=50000)

# Save the model
model.save("ppo_hems_agent")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 from stable_baselines3.common.vec_env import DummyVecEnv
#       5 # Wrap your environment
# ----> 6 env = HEMSEnv()
#       7 check_env(env)  # Validate compatibility
#       8 vec_env = DummyVecEnv([lambda: env])
#
# NameError: name 'HEMSEnv' is not defined

# %%
# Load the model
model = PPO.load("ppo_hems_agent")
state = env.reset()
done = False

while not done:
    action, _ = model.predict(state)
    state, reward, done, _ = env.step(action)
    print(f"Action: {action}, Reward: {reward:.2f}")
